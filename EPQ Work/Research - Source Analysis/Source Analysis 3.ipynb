# %% [markdown]
# <div align="left"><table border="0" align=left>
#  <tr>
#     <td>Type of source</td>
#     <td>Scholarly publication</td>
#  </tr>
#  <tr>
#     <td>Publication Date</td>
#     <td>April 2020</td>
#  </tr>
#   <tr>
#     <td>Author</td>
#     <td>Debajit Datta, Preetha Evangeline David, Dhruv Mittal, Anukriti Jain</td>
#  </tr>
#  <tr>
#     <td>Key Quotes</td>
#     <td>“it can be clearly seen that the Recurrent Neural Network with encoding is having the highest accuracy”
#
#
# “From the plot visualized in Fig. 3, the new RNN model that is created by merging of two previous RNN models, namely, bidirectional RNN and RNN with embedding, the accuracy is almost a cent percent”
#
#
#
# “The work can be extended for a larger dataset consisting of even bigger text corpus, so that the system becomes ideal for translating every possible sentence”
#
#
# “The benefit of using RNN in our project is that it will allow us to work on sequential data i.e. we can have words and sentences in a text which are based on previous context as well. This can’t be achieved using ANN.”
# </td>
#  </tr>
#  <tr>
#     <td>Purpose and significance</td>
#     <td>The article shows that merged RNN models are much more effective than ANN models at neural machine translation, due to the ability to store and recall context.
#
# It also shows that RNN models with embedding greatly outperform other neural networks.
# </td>
#  </tr>
#  <tr>
#     <td>Main Ideas</td>
#     <td>The article argues that RNN models are much better for machine translation than ANN models. As such, they should be used over ANN models in this context. It backs this up using data that proves their point.</td>
#  </tr>
#   <tr>
#     <td>What research questions does it answer?</td>
#     <td style="color: red;">It answers the question of which kind of neural network I should use for maximum accuracy of translation; a recurrent neural network. It also begins to answer the question of which type of recurrent neural network I should use, with bidirectional and word embedding’s both being considerations for the final model.</td>
#  </tr>
#  <tr>
#     <td>Do you agree?</td>
#     <td>Yes, as the data provided is very convincing.</td>
#  </tr>
#  <tr>
#     <td>What needs further research</td>
#     <td style="color: red;">Research (Recurrent Neural Network with Embedding, Bidirectional Recurrent Neural Network, and Recurrent Neural Network with embedded encoder and decoder.)</td>
#  </tr>
#  <tr>
#     <td>References (hyperlink this)</td>
#     <td style="color: red;">The paper [0]
#         The research by Shadiev et. al. [1]
# The work of Soltau et. al. [2]
# According to Xiong et. al. [3]
# The paper presented by Shang et. al. [4]
# </td>
#  </tr>
#   <tr>
#     <td>Is there anything missing or wrong with the source?</td>
#     <td>Not to my knowledge.</td>
#  </tr>
#  <tr>
#     <td>Evaluation</td>
#     <td style="color: red;" >This source is very helpful in my research for deciding on my approach to the problem, and for directing me to further sources to deepen my understanding of the topic. research reasons.</td>
#  </tr>
#   <tr>
#     <td>Conclusion</td>
#     <td>This source does not cover many of the aspects of my project, but will he very helpful in choosing an approach to the problem, as well as refining that approach using it’s provided data.</td>
#  </tr>
# </table></div>
